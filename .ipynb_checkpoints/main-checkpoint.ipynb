# %%
import pandas as pd
from xerparser.reader import Reader


def read_xer_file(file):
    xer = Reader(file)

    # Initialize empty lists
    project_names = []
    activity_counts = []
    wbs_names = []
    task_names = []
    start_dates = []
    end_dates = []
    duration = []
    ids = []
    constraints = []
    drivingPathFlag=[]
    freeFloat=[]
    task_type=[]
    totalFloat=[]
    calendar=[]
    activitycodes=[]
    task_id=[]


    # Loop through each project in XER file
    for project in xer.projects:
        # Get activity count for current project
        num_activities = len(project.activities)
        
        # Store project name and activity count
        project_names += [project.proj_short_name] * num_activities
        activity_counts += [num_activities] * num_activities
        
        # Loop through each WBS in project
        for wbs in project.wbss:
            # Store WBS name
            wbs_names += [wbs.wbs_name] * len(wbs.activities)
            
            # Loop through each activity in WBS
            
            for act in wbs.activities:
                # print (dir(act))
                task_names.append(act.task_name)
                start_dates.append(act.start_date)
                end_dates.append(act.end_date)
                ids.append(act.id)
                task_id.append(act.task_id)
                duration.append(act.duration)
        

                constraints.append(act.constraints)
                drivingPathFlag.append(act.driving_path_flag)
                freeFloat.append(act.free_float_hr_cnt)
                task_type.append(act.task_type)
                totalFloat.append(act.total_float_hr_cnt)
                calendar.append(act.calendar)
                activitycodes.append(act.activitycodes)
    # Create a DataFrame from the collected data
    df = pd.DataFrame({
        'ID': ids,
        'Project Name': project_names,
        'Activity Count': activity_counts,
        'WBS Name': wbs_names,
        'Task Name': task_names,
        'Start Date': start_dates,
        'End Date': end_dates,
        'Duration': duration,
        'Constraints': constraints,
        'Driving Path Flag': drivingPathFlag,
        'Free Float': freeFloat,
        'Task Type': task_type,
        'Total Float': totalFloat,
        'Calendar': calendar,
        'Activity Codes': activitycodes,
        'Task ID': task_id,
    })

    return df

file = r"xer/Sample_Xer_02.xer"

df = read_xer_file(file)
  
print(df.head())
# Out:
#         ID Project Name  Activity Count       WBS Name  \
# 0   185546     Baseline              27          CIVIL
# 1   185547     Baseline              27      LONG LEAD
# 2   185548     Baseline              27      LONG LEAD
# 3   185549     Baseline              27      LONG LEAD
# 4   185550     Baseline              27      LONG LEAD
# 5   185551     Baseline              27      LONG LEAD
# 6   185552     Baseline              27      LONG LEAD
# 7   185553     Baseline              27          CIVIL
# 8   185554     Baseline              27          CIVIL
# 9   185555     Baseline              27          CIVIL
# 10  185556     Baseline              27          CIVIL
# 11  185557     Baseline              27     MECHANICAL
# 12  185558     Baseline              27         PIPING
# 13  185559     Baseline              27         PIPING
# 14  185561     Baseline              27     MECHANICAL
# 15  185562     Baseline              27         PIPING
# 16  185563     Baseline              27         PIPING
# 17  185560     Baseline              27          CIVIL
# 18  185564     Baseline              27          CIVIL
# 19  185565     Baseline              27     MECHANICAL
# 20  185566     Baseline              27         PIPING
# 21  185567     Baseline              27         PIPING
# 22  185568     Baseline              27          CIVIL
# 23  185569     Baseline              27     MECHANICAL
# 24  185570     Baseline              27         PIPING
# 25  185571     Baseline              27         PIPING
# 26  185572     Baseline              27  COMMISSIONING
#
#                          Task Name          Start Date            End Date  \
# 0       CIVIL WORKS GENERAL LAYOUT 2012-01-01 00:00:00 2012-01-15 18:00:00
# 1    Pump -  Request for Quotation 2012-01-15 18:00:00 2012-02-14 17:00:00
# 2            Pump -  Bidding Phase 2012-02-14 17:00:00 2012-02-21 16:00:00
# 3    Pump -  Commercial Evaluation 2012-02-21 16:00:00 2012-03-06 15:00:00
# 4           Pump -  Purchase Order 2012-03-06 15:00:00 2012-03-31 14:00:00
# 5            Pump -  Manufacturing 2012-03-31 14:00:00 2012-05-31 13:00:00
# 6        Pump -  Transport to Site 2012-05-31 13:00:00 2012-07-11 12:00:00
# 7                 Top soil removal 2012-11-13 12:00:00 2012-12-12 00:00:00
# 8              GENERAL EXCAVATIONS 2012-12-12 00:00:00 2012-12-26 18:00:00
# 9   General backfil. of area/roads 2012-12-26 18:00:00 2013-02-20 18:00:00
# 10          Foundation Civil Works 2012-01-01 00:00:00 2012-01-29 12:00:00
# 11     EREC.OF ASSEMBLED MACHINERY 2012-01-29 12:00:00 2012-02-26 00:00:00
# 12   INSUL.OF HOT & TRACED EQUIPM. 2012-02-26 00:00:00 2012-03-10 18:00:00
# 13  FIN.COAT FOR MACH./MEC.LIFTING 2012-03-10 18:00:00 2012-03-15 08:00:00
# 14     EREC.OF ASSEMBLED MACHINERY 2012-04-11 20:00:00 2012-04-25 14:00:00
# 15   INSUL.OF HOT & TRACED EQUIPM. 2012-04-25 14:00:00 2012-05-23 02:00:00
# 16  FIN.COAT FOR MACH./MEC.LIFTING 2012-05-23 02:00:00 2012-05-30 12:00:00
# 17          Foundation Civil Works 2012-03-15 08:00:00 2012-04-11 20:00:00
# 18          Foundation Civil Works 2012-05-30 12:00:00 2012-06-27 00:00:00
# 19     EREC.OF ASSEMBLED MACHINERY 2012-06-27 00:00:00 2012-07-11 18:00:00
# 20   INSUL.OF HOT & TRACED EQUIPM. 2012-07-11 18:00:00 2012-08-08 06:00:00
# 21  FIN.COAT FOR MACH./MEC.LIFTING 2012-08-08 06:00:00 2012-09-14 22:00:00
# 22          Foundation Civil Works 2012-09-14 22:00:00 2012-10-03 06:00:00
# 23     EREC.OF ASSEMBLED MACHINERY 2012-10-03 06:00:00 2012-10-17 00:00:00
# 24   INSUL.OF HOT & TRACED EQUIPM. 2012-10-17 00:00:00 2012-10-30 18:00:00
# 25  FIN.COAT FOR MACH./MEC.LIFTING 2012-10-30 18:00:00 2012-11-13 12:00:00
# 26        Commissioning Air system 2012-07-11 12:00:00 2012-07-25 06:00:00
#
#      Duration Constraints Driving Path Flag  Free Float Task Type  \
# 0   13.750000        None                 N         0.0   TT_Task
# 1   29.958333        None                 N         0.0   TT_Task
# 2    6.958333        None                 N         0.0   TT_Task
# 3   13.958333        None                 N         0.0   TT_Task
# 4   24.958333        None                 N         0.0   TT_Task
# 5   59.958333        None                 N         0.0   TT_Task
# 6   39.958333        None                 N         0.0   TT_Task
# 7   27.500000        None                 Y         0.0   TT_Task
# 8   13.750000        None                 Y         0.0   TT_Task
# 9   55.000000        None                 Y         0.0   TT_Task
# 10  27.500000        None                 Y         0.0   TT_Task
# 11  27.500000        None                 Y         0.0   TT_Task
# 12  13.750000        None                 Y         0.0   TT_Task
# 13   4.583333        None                 Y         0.0   TT_Task
# 14  13.750000        None                 Y         0.0   TT_Task
# 15  27.500000        None                 Y         0.0   TT_Task
# 16   6.416667        None                 Y         0.0   TT_Task
# 17  27.500000        None                 Y         0.0   TT_Task
# 18  27.500000        None                 Y         0.0   TT_Task
# 19  13.750000        None                 Y         0.0   TT_Task
# 20  27.500000        None                 Y         0.0   TT_Task
# 21  36.666667        None                 Y         0.0   TT_Task
# 22  18.333333        None                 Y         0.0   TT_Task
# 23  13.750000        None                 Y         0.0   TT_Task
# 24  13.750000        None                 Y         0.0   TT_Task
# 25  13.750000        None                 Y         0.0   TT_Task
# 26  13.750000        None                 N      4956.0   TT_Task
#
#     Total Float                                           Calendar  \
# 0        4956.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 1        4956.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 2        4956.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 3        4956.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 4        4956.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 5        4956.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 6        4956.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 7           0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 8           0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 9           0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 10          0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 11          0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 12          0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 13          0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 14          0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 15          0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 16          0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 17          0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 18          0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 19          0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 20          0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 21          0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 22          0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 23          0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 24          0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 25          0.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
# 26       4956.0  7x24 : 24.0\n(0||CalendarData()(  (0||DaysOf...
#
#    Activity Codes  Task ID
# 0              []   185546
# 1              []   185547
# 2              []   185548
# 3              []   185549
# 4              []   185550
# 5              []   185551
# 6              []   185552
# 7              []   185553
# 8              []   185554
# 9              []   185555
# 10             []   185556
# 11             []   185557
# 12             []   185558
# 13             []   185559
# 14             []   185561
# 15             []   185562
# 16             []   185563
# 17             []   185560
# 18             []   185564
# 19             []   185565
# 20             []   185566
# 21             []   185567
# 22             []   185568
# 23             []   185569
# 24             []   185570
# 25             []   185571
# 26             []   185572
